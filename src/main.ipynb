# %%
from urllib.request import urlopen
import warnings

import pandas as pd

import cmasher as cmr
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from highlight_text import ax_text

from mplsoccer import Pitch, VerticalPitch, add_image, FontManager, Sbopen

# %%
parser = Sbopen(dataframe=True)
competition = parser.competition()
ucl = competition[competition['competition_name'] == 'Champions League']
match = parser.match(competition_id=16, season_id=4)
match
# Out:
#    match_id match_date            kick_off  home_score  away_score  \
# 0     22912 2019-06-01 2019-06-01 21:00:00           0           2
#
#   match_status match_status_360               last_updated  \
# 0    available        scheduled 2022-11-28 14:45:35.628134
#
#          last_updated_360  match_week  ...  competition_stage_id  \
# 0 2021-06-13 16:17:31.694          13  ...                    26
#
#   competition_stage_name stadium_id                     stadium_name  \
# 0                  Final       4654  \tEstádio Cívitas Metropolitano
#
#   stadium_country_id  stadium_country_name referee_id   referee_name  \
# 0                214                 Spain        420  Damir Skomina
#
#   referee_country_id  referee_country_name
# 0                208              Slovenia
#
# [1 rows x 52 columns]

# %%
ev = parser.event(22912)
df = pd.concat(ev)
df
# Out:
#                                       id  index  period        timestamp  \
# 0   9ec3d009-c15b-4a8d-be80-57a07f40755a    1.0     1.0         00:00:00
# 1   e8bdb5d1-8bcb-4a0d-bfd2-68c18c7f54d0    2.0     1.0         00:00:00
# 2   00b678a4-3767-4d0b-92e6-9cb4c959d94d    3.0     1.0         00:00:00
# 3   05840f64-0fb7-4f2d-885a-49790d6bd4df    4.0     1.0         00:00:00
# 4   b67ef6a9-e877-4dbe-bb03-edcc9d8c7711    5.0     1.0  00:00:00.208000
# ..                                   ...    ...     ...              ...
# 61  9d4982b9-476a-465e-8a4b-8b943054130d    NaN     NaN              NaN
# 62  9d4982b9-476a-465e-8a4b-8b943054130d    NaN     NaN              NaN
# 63  9d4982b9-476a-465e-8a4b-8b943054130d    NaN     NaN              NaN
# 64  9d4982b9-476a-465e-8a4b-8b943054130d    NaN     NaN              NaN
# 65  9d4982b9-476a-465e-8a4b-8b943054130d    NaN     NaN              NaN
#
#     minute  second  possession  duration  match_id  type_id  ...  \
# ...

# %%
events, related, tactics, freeze = parser.event(22912)

df = events[['team_name', 'player_name', 'pass_recipient_name', 'position_name', 'x', 'y', 'end_x', 'end_y', 'outcome_name', 'under_pressure', 'technique_id']]

liv_df = df[(df['team_name'] == 'Liverpool') & (df['player_name'] == 'Trent Alexander-Arnold') & (df['under_pressure'] == 1.00)]
liv_df
# Out:
#       team_name             player_name pass_recipient_name position_name  \
# 216   Liverpool  Trent Alexander-Arnold                 NaN    Right Back
# 217   Liverpool  Trent Alexander-Arnold                 NaN    Right Back
# 219   Liverpool  Trent Alexander-Arnold                 NaN    Right Back
# 461   Liverpool  Trent Alexander-Arnold                 NaN    Right Back
# 671   Liverpool  Trent Alexander-Arnold                 NaN    Right Back
# 1079  Liverpool  Trent Alexander-Arnold                 NaN    Right Back
# 1081  Liverpool  Trent Alexander-Arnold       Mohamed Salah    Right Back
# 1447  Liverpool  Trent Alexander-Arnold                 NaN    Right Back
# 1449  Liverpool  Trent Alexander-Arnold       Mohamed Salah    Right Back
# 1709  Liverpool  Trent Alexander-Arnold                 NaN    Right Back
# 2037  Liverpool  Trent Alexander-Arnold                 NaN    Right Back
# 2937  Liverpool  Trent Alexander-Arnold                 NaN    Right Back
#
# ...
